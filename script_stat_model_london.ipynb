# %%
import pandas as pd
import numpy as np

# %%
#Lecture de la base des données
df = pd.read_csv("df_final_london.csv")

# %% [markdown]
# # STATISTIQUES DESCRIPTIVES

# %%
df.head()
# Out:
#          Date  MAX_TEMPERATURE_C  MIN_TEMPERATURE_C  TEMP_MOY  \
# 0  2024-01-01                 10                  7      8.00
# 1  2024-01-02                 12                  9     10.75
# 2  2024-01-03                 11                 10     10.25
# 3  2024-01-04                  8                  6      7.25
# 4  2024-01-05                  7                  4      5.25
#
#    HUMIDITY_MAX_PERCENT  HUMIDITY_EST_AVG  WINDSPEED_MAX_KMH  \
# 0                    77             57.75                 22
# 1                    94             70.50                 41
# 2                    75             56.25                 28
# 3                    83             62.25                 17
# 4                    85             63.75                 21
#
#    WINDSPEED_AVG_KMH  PRECIP_TOTAL_DAY_MM  SUNHOUR  ...   Toluène   Benzène  \
# 0               13.2                  0.7        1  ...  1.220990  0.557676
# 1               24.6                  3.3        1  ...  0.798221  0.362716
# 2               16.8                  0.3        1  ...  0.961362  0.431034
# 3               10.2                  0.5        3  ...  1.940256  0.602937
# 4               12.6                  2.9        7  ...  0.938934  0.445602
#
#            CO        NO2       SO2         O3      PM2.5       PM10  \
# 0  173.625000  16.883333  3.025000  54.750000   5.029167   8.579167
# 1  147.458333  13.370833  2.262500  63.208333   4.125000   6.500000
# 2  175.041667  17.875000  2.929167  51.000000   5.612500   7.675000
# 3  199.125000  29.491667  4.762500  38.041667   7.000000  11.658333
# 4  207.333333  26.400000  4.762500  31.833333  12.687500  14.954167
#
#          AQI    City
# 0  21.411284  London
# 1  25.283333  London
# 2  21.110833  London
# 3  21.359653  London
# 4  19.680278  London
#
# [5 rows x 23 columns]

# %%
df.describe()
# Out:
#        MAX_TEMPERATURE_C  MIN_TEMPERATURE_C    TEMP_MOY  HUMIDITY_MAX_PERCENT  \
# count         366.000000         366.000000  366.000000            366.000000
# mean           15.079235           9.193989   11.890027             83.221311
# std             5.869985           4.291829    4.889956              9.504588
# min             2.000000          -1.000000    0.000000             54.000000
# 25%            11.000000           6.000000    8.000000             76.000000
# 50%            15.000000           9.000000   11.875000             84.000000
# 75%            19.000000          12.000000   15.500000             91.000000
# max            33.000000          19.000000   25.250000             99.000000
#
#        HUMIDITY_EST_AVG  WINDSPEED_MAX_KMH  WINDSPEED_AVG_KMH  \
# count        366.000000         366.000000         366.000000
# mean          62.415984          17.071038          10.242623
# std            7.128441           6.593096           3.955857
# min           40.500000           3.000000           1.800000
# 25%           57.000000          12.250000           7.350000
# 50%           63.000000          17.000000          10.200000
# 75%           68.250000          21.000000          12.600000
# max           74.250000          41.000000          24.600000
#
#        PRECIP_TOTAL_DAY_MM     SUNHOUR  SR_EST_W_m2  ...  \
# count           366.000000  366.000000   366.000000  ...
# mean              0.603825    6.751366  1012.704918  ...
# std               1.139953    4.386897   658.034479  ...
# min               0.000000    1.000000   150.000000  ...
# 25%               0.000000    3.000000   450.000000  ...
# 50%               0.100000    7.000000  1050.000000  ...
# 75%               0.700000   10.000000  1500.000000  ...
# max               7.900000   17.000000  2550.000000  ...
#
#        CLOUDCOVER_AVG_PERCENT     Toluène     Benzène          CO         NO2  \
# count              366.000000  366.000000  366.000000  366.000000  366.000000
# mean                58.742828    1.479450    0.509607  187.744194   21.797495
# std                 26.607622    0.846281    0.188994   40.200822   11.470910
# min                  0.625000    0.239787    0.149434  117.333333    5.804167
# 25%                 38.281250    1.072107    0.397704  159.833333   13.287500
# 50%                 62.937500    1.479450    0.509607  181.291667   18.454167
# 75%                 81.062500    1.726478    0.562612  207.572917   28.227083
# max                100.000000   12.168312    1.593183  358.500000   72.579167
#
#               SO2          O3       PM2.5        PM10         AQI
# count  366.000000  366.000000  366.000000  366.000000  366.000000
# mean     3.326093   49.154030    9.985178   14.136009   27.097212
# std      2.399183   17.204380    5.689122    6.555239    8.662264
# min      0.637500    3.541667    1.666667    3.287500   15.926389
# 25%      1.685417   38.968750    5.896875    9.613542   22.232084
# 50%      2.552083   51.916667    8.239583   12.466667   24.824792
# 75%      4.153125   60.572917   12.318750   16.917708   28.871615
# max     15.662500   94.375000   34.533333   43.333333   69.008472
#
# [8 rows x 21 columns]

# %%
df.isnull().sum()
# Out:
# Date                      0
# MAX_TEMPERATURE_C         0
# MIN_TEMPERATURE_C         0
# TEMP_MOY                  0
# HUMIDITY_MAX_PERCENT      0
# HUMIDITY_EST_AVG          0
# WINDSPEED_MAX_KMH         0
# WINDSPEED_AVG_KMH         0
# PRECIP_TOTAL_DAY_MM       0
# SUNHOUR                   0
# SR_EST_W_m2               0
# PRESSURE_MAX_MB           0
# CLOUDCOVER_AVG_PERCENT    0
# Toluène                   0
# Benzène                   0
# CO                        0
# NO2                       0
# SO2                       0
# O3                        0
# PM2.5                     0
# PM10                      0
# AQI                       0
# City                      0
# dtype: int64

# %% [markdown]
# ## Outliers

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Sélection des colonnes numériques
numeric_cols = df.select_dtypes(include=['number']).columns

# Définir la taille de la figure pour les boxplots
plt.figure(figsize=(15, len(numeric_cols) * 2.5))

# Générer les boxplots
for i, col in enumerate(numeric_cols, 1):
    plt.subplot(len(numeric_cols), 1, i)
    sns.boxplot(x=df[col], orient='h')
    plt.title(f'Boxplot de {col}')
    plt.tight_layout()

plt.show()

# %% [markdown]
# #### Traitement des valeurs extrêmes (outliers)
# Dans cette étude, les valeurs extrêmes présentes dans les données n’ont pas été supprimées ni imputées. Cette décision repose sur le fait que, dans le contexte de la qualité de l’air, les outliers peuvent représenter des événements environnementaux réels et significatifs tels que des pics de pollution liés à des conditions météorologiques particulières, des épisodes de trafic intense ou d'autres incidents ponctuels. Les exclure reviendrait à ignorer des signaux critiques dans l’analyse. Afin de préserver l’intégrité des données et de refléter fidèlement leur variabilité naturelle, nous avons opté pour l’utilisation de modèles robustes (notamment la régression avec norme de Huber) qui permettent de limiter l’impact des valeurs extrêmes sans pour autant les écarter. Ce choix vise à assurer à la fois la validité scientifique de l’analyse et la pertinence opérationnelle des résultats, notamment pour la détection et l’interprétation des épisodes de pollution atypiques.

# %%
# Transformation de la variable cible (log AQI)
df['log_AQI'] = np.log(df['AQI'] + 1)

df['log_AQI'] = df['log_AQI'].astype(float)

# %% [markdown]
# ## Distribution des variables

# %%
numeric_columns = df.select_dtypes(include=np.number).columns

# Définir la taille de la figure
n_cols = 3
n_rows = int(np.ceil(len(numeric_columns) / n_cols))
fig, axes = plt.subplots(n_rows, n_cols, figsize=(18, n_rows * 4))
axes = axes.flatten()

# Créer un histogramme avec courbe de densité pour chaque variable
for i, col in enumerate(numeric_columns):
    sns.histplot(df[col], kde=True, ax=axes[i], bins=30)
    axes[i].set_title(f'Distribution de {col}')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Fréquence')

# Supprimer les axes vides si le nombre de variables < nombre de sous-graphiques
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Corrélation entre les variables

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculer la matrice de corrélation
correlation_matrix = df.corr(numeric_only=True)

# Définir la taille de la figure
plt.figure(figsize=(14, 12))

# Créer une heatmap avec annotations
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True, linewidths=0.5)

plt.title("Matrice de corrélation des variables numériques")
plt.tight_layout()
plt.show()

# %%
print(df.columns)
# Out:
# Index(['Date', 'MAX_TEMPERATURE_C', 'MIN_TEMPERATURE_C', 'TEMP_MOY',
#        'HUMIDITY_MAX_PERCENT', 'HUMIDITY_EST_AVG', 'WINDSPEED_MAX_KMH',
#        'WINDSPEED_AVG_KMH', 'PRECIP_TOTAL_DAY_MM', 'SUNHOUR', 'SR_EST_W_m2',
#        'PRESSURE_MAX_MB', 'CLOUDCOVER_AVG_PERCENT', 'Toluène', 'Benzène', 'CO',
#        'NO2', 'SO2', 'O3', 'PM2.5', 'PM10', 'AQI', 'City', 'log_AQI'],
#       dtype='object')

# %% [markdown]
# ## Corrélations entre AQI et les autres variables

# %%
# Corrélations avec AQI uniquement (triées)
corr_with_aqi = correlation_matrix[['AQI']].sort_values(by='AQI', ascending=False)

# Identification des couples de variables très fortement corrélées (> 0.8), en excluant la diagonale
high_corr_pairs = []
threshold = 0.8
for i in range(len(correlation_matrix.columns)):
    for j in range(i + 1, len(correlation_matrix.columns)):
        var1 = correlation_matrix.columns[i]
        var2 = correlation_matrix.columns[j]
        corr_value = correlation_matrix.iloc[i, j]
        if abs(corr_value) > threshold:
            high_corr_pairs.append((var1, var2, corr_value))

# Conversion en DataFrame pour affichage
high_corr_df = pd.DataFrame(high_corr_pairs, columns=['Variable 1', 'Variable 2', 'Corrélation'])

print("Corrélations avec AQI (triées) :")
print(corr_with_aqi)

print("\nPaires de variables très fortement corrélées (> 0.8) :")#ce sont des cas potentiels de multicolinéarité, à surveiller dans les modèles linéaires.
print(high_corr_df)
# Out:
# Corrélations avec AQI (triées) :
#                              AQI
# AQI                     1.000000
# log_AQI                 0.979089
# PM2.5                   0.783115
# PM10                    0.759597
# CO                      0.575242
# SO2                     0.533581
# NO2                     0.450169
# Benzène                 0.295983
# PRESSURE_MAX_MB         0.144531
# SUNHOUR                 0.117593
# SR_EST_W_m2             0.117593
# Toluène                 0.030955
# HUMIDITY_MAX_PERCENT   -0.013412
# HUMIDITY_EST_AVG       -0.013412
# MAX_TEMPERATURE_C      -0.018911
# TEMP_MOY               -0.036279
# MIN_TEMPERATURE_C      -0.044700
# PRECIP_TOTAL_DAY_MM    -0.125543
# O3                     -0.217615
# WINDSPEED_MAX_KMH      -0.234404
# WINDSPEED_AVG_KMH      -0.234404
# CLOUDCOVER_AVG_PERCENT -0.235772
#
# Paires de variables très fortement corrélées (> 0.8) :
#               Variable 1              Variable 2  Corrélation
# 0      MAX_TEMPERATURE_C       MIN_TEMPERATURE_C     0.916039
# 1      MAX_TEMPERATURE_C                TEMP_MOY     0.976662
# 2      MIN_TEMPERATURE_C                TEMP_MOY     0.971033
# 3   HUMIDITY_MAX_PERCENT        HUMIDITY_EST_AVG     1.000000
# 4      WINDSPEED_MAX_KMH       WINDSPEED_AVG_KMH     1.000000
# 5                SUNHOUR             SR_EST_W_m2     1.000000
# 6                SUNHOUR  CLOUDCOVER_AVG_PERCENT    -0.817307
# 7            SR_EST_W_m2  CLOUDCOVER_AVG_PERCENT    -0.817307
# 8                     CO                     NO2     0.815882
# 9                     CO                     SO2     0.851154
# 10                    CO                   PM2.5     0.815433
# 11                   NO2                     SO2     0.882323
# 12                   NO2                      O3    -0.822468
# 13                 PM2.5                    PM10     0.973832
# 14                   AQI                 log_AQI     0.979089

# %%
# Conversion de la date au bon forma
df['Date'] = pd.to_datetime(df['Date'])
# Création des variables temporelles
df['day'] = df['Date'].dt.day
df['month'] = df['Date'].dt.month
df['weekday'] = df['Date'].dt.weekday
df['week'] = df['Date'].dt.isocalendar().week
df['year'] = df['Date'].dt.year
df['TimeIndex'] = np.arange(len(df))

# Optionnel : ajouter une variable "saison"
def get_season(month):
    if month in [12, 1, 2]:
        return 'hiver'
    elif month in [3, 4, 5]:
        return 'printemps'
    elif month in [6, 7, 8]:
        return 'été'
    else:
        return 'automne'

df['saison'] = df['month'].apply(get_season)
df = pd.get_dummies(df, columns=['saison'], drop_first=True)

# %%
df.head()
# Out:
#         Date  MAX_TEMPERATURE_C  MIN_TEMPERATURE_C  TEMP_MOY  \
# 0 2024-01-01                 10                  7      8.00
# 1 2024-01-02                 12                  9     10.75
# 2 2024-01-03                 11                 10     10.25
# 3 2024-01-04                  8                  6      7.25
# 4 2024-01-05                  7                  4      5.25
#
#    HUMIDITY_MAX_PERCENT  HUMIDITY_EST_AVG  WINDSPEED_MAX_KMH  \
# 0                    77             57.75                 22
# 1                    94             70.50                 41
# 2                    75             56.25                 28
# 3                    83             62.25                 17
# 4                    85             63.75                 21
#
#    WINDSPEED_AVG_KMH  PRECIP_TOTAL_DAY_MM  SUNHOUR  ...   log_AQI  day  month  \
# 0               13.2                  0.7        1  ...  3.109565    1      1
# 1               24.6                  3.3        1  ...  3.268935    2      1
# 2               16.8                  0.3        1  ...  3.096068    3      1
# 3               10.2                  0.5        3  ...  3.107258    4      1
# 4               12.6                  2.9        7  ...  3.029180    5      1
#
#    weekday  week  year  TimeIndex  saison_hiver  saison_printemps  saison_été
# 0        0     1  2024          0          True             False       False
# 1        1     1  2024          1          True             False       False
# 2        2     1  2024          2          True             False       False
# 3        3     1  2024          3          True             False       False
# 4        4     1  2024          4          True             False       False
#
# [5 rows x 33 columns]

# %%
df['log_AQI_lag1'] = df['log_AQI'].shift(1)
df.dropna(inplace=True)  # pour enlever la première ligne avec NaN

# %% [markdown]
# # ECONOMETRIE

# %%
# 📦 Importation des bibliothèques nécessaires
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.robust.robust_linear_model import RLM
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.stats.diagnostic import het_breuschpagan, normal_ad

# %%
# Sélection des variables explicatives
# ✅ Variables explicatives sélectionnées selon la littérature et la corrélation avec log_AQI
features = ['PM2.5',
            #'PM10',
            #'CO', 
            'SO2' ,
            #'NO2',
            'Benzène',
            'PRESSURE_MAX_MB',
            #'SUNHOUR',                 
            #'SR_EST_W_m2' ,            
            'Toluène',                 
            'HUMIDITY_MAX_PERCENT',   
            #'HUMIDITY_EST_AVG',       
            #'MAX_TEMPERATURE_C',      
            #'TEMP_MOY',               
            #'MIN_TEMPERATURE_C',      
            'PRECIP_TOTAL_DAY_MM',    
            'O3',                     
            'WINDSPEED_MAX_KMH',     
            #'WINDSPEED_AVG_KMH',      
            'CLOUDCOVER_AVG_PERCENT',
            'weekday',
            'month',
            'saison_hiver',
            'saison_été',
            'saison_printemps',
            'log_AQI_lag1',
]
X = df[features]
X = X.loc[:, ~X.columns.duplicated()]  # Supprimer les colonnes dupliquées
X = sm.add_constant(X)
y = df['log_AQI']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.stats.stattools import durbin_watson
# Nettoyage pour RLM
X = X.apply(lambda col: col.astype(float))
y = y.astype(float)

def verifier_rlm_robuste(X, y):
    # Ajout de la constante
    X_const = sm.add_constant(X)
    
    
    # Estimation du modèle RLM avec norme de Huber
    model_rlm = sm.RLM(y, X_const, M=sm.robust.norms.HuberT())
    results_rlm = model_rlm.fit()

    # Résumé
    print("\n✅ RÉSUMÉ DU MODÈLE ROBUSTE (RLM - Huber)")
    print(results_rlm.summary())
    
    # 1. Graphique Résidus vs Prédictions (linéarité)
    plt.figure()
    plt.scatter(results_rlm.fittedvalues, results_rlm.resid)
    plt.axhline(0, color='red', linestyle='--')
    plt.xlabel("Valeurs prédites")
    plt.ylabel("Résidus")
    plt.title("Test visuel de linéarité (Résidus vs Prédictions - RLM)")
    plt.show()

    # 2. VIF - Multicolinéarité
    print("\n📊 VIF - Facteurs d'inflation de la variance")
    vif_data = pd.DataFrame()
    vif_data["Variable"] = X_const.columns
    vif_data["VIF"] = [variance_inflation_factor(X_const.values, i) for i in range(X_const.shape[1])]
    print(vif_data)

    # 3. Durbin-Watson (Indépendance des erreurs)
    print("\n📊 Indépendance des erreurs - Durbin-Watson")
    dw_stat = durbin_watson(results_rlm.resid)
    print(f"Durbin-Watson statistic : {dw_stat:.3f} (idéal proche de 2)")

    # 4. Boxplot des résidus (détection d’outliers)
    plt.figure()
    sns.boxplot(x=results_rlm.resid)
    plt.title("Boxplot des résidus (pour détecter les outliers)")
    plt.show()

    return results_rlm
results_rlm = verifier_rlm_robuste(X, y)

# y : variable observée (log_AQI)
# y_pred : prédictions du modèle RLM
# y.mean() : moyenne des valeurs observées

y_pred = results_rlm.predict(sm.add_constant(X))

ss_total = np.sum((y - y.mean())**2)
ss_residual = np.sum((y - y_pred)**2)
r2_robust = 1 - (ss_residual / ss_total)

print(f"R² (pseudo) du modèle RLM : {r2_robust:.4f}")
# Out:
# ✅ RÉSUMÉ DU MODÈLE ROBUSTE (RLM - Huber)
#                     Robust linear Model Regression Results
# ==============================================================================
# Dep. Variable:                log_AQI   No. Observations:                  365
# Model:                            RLM   Df Residuals:                      348
# Method:                          IRLS   Df Model:                           16
# Norm:                          HuberT
# Scale Est.:                       mad
# Cov Type:                          H1
# Date:                Wed, 16 Jul 2025
# Time:                        12:07:07
# No. Iterations:                    25
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      0.4592      0.675      0.680      0.496      -0.864       1.782
# PM2.5                      0.0306      0.002     17.653      0.000       0.027       0.034
# SO2                        0.0419      0.006      7.608      0.000       0.031       0.053
# Benzène                    0.0348      0.043      0.807      0.419      -0.050       0.119
# PRESSURE_MAX_MB            0.0009      0.001      1.380      0.168      -0.000       0.002
# Toluène                   -0.0130      0.008     -1.683      0.092      -0.028       0.002
# HUMIDITY_MAX_PERCENT    9.826e-05      0.001      0.140      0.888      -0.001       0.001
# PRECIP_TOTAL_DAY_MM        0.0023      0.006      0.409      0.683      -0.009       0.013
# O3                         0.0071      0.001     11.710      0.000       0.006       0.008
# WINDSPEED_MAX_KMH          0.0082      0.001      7.530      0.000       0.006       0.010
# CLOUDCOVER_AVG_PERCENT  3.328e-05      0.000      0.123      0.902      -0.000       0.001
# weekday                    0.0101      0.003      3.846      0.000       0.005       0.015
# month                      0.0119      0.002      5.617      0.000       0.008       0.016
# saison_hiver              -0.0012      0.020     -0.061      0.951      -0.040       0.038
# saison_été                 0.0439      0.018      2.442      0.015       0.009       0.079
# saison_printemps           0.0378      0.021      1.805      0.071      -0.003       0.079
# log_AQI_lag1               0.2622      0.024     10.778      0.000       0.215       0.310
# ==========================================================================================
#
# If the model instance has been used for another fit with different fit parameters, then the fit options might not be the correct ones anymore .
# 📊 VIF - Facteurs d'inflation de la variance
#                   Variable           VIF
# 0                    const  17472.822203
# 1                    PM2.5      3.718306
# 2                      SO2      6.690180
# 3                  Benzène      2.545784
# 4          PRESSURE_MAX_MB      1.651294
# 5                  Toluène      1.639768
# 6     HUMIDITY_MAX_PERCENT      1.697928
# 7      PRECIP_TOTAL_DAY_MM      1.577868
# 8                       O3      4.112269
# 9        WINDSPEED_MAX_KMH      1.971734
# 10  CLOUDCOVER_AVG_PERCENT      1.976552
# 11                 weekday      1.061390
# 12                   month      2.052571
# 13            saison_hiver      2.793582
# 14              saison_été      2.336039
# 15        saison_printemps      3.173670
# 16            log_AQI_lag1      1.412770
#
# 📊 Indépendance des erreurs - Durbin-Watson
# Durbin-Watson statistic : 2.276 (idéal proche de 2)
# R² (pseudo) du modèle RLM : 0.8103

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

mae = mean_absolute_error(y, y_pred)
rmse = np.sqrt(mean_squared_error(y, y_pred))

print(f"MAE : {mae:.4f}")
print(f"RMSE : {rmse:.4f}")
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np
# Out:
# MAE : 0.0798
# RMSE : 0.1076

# %% [markdown]
# * **MAE (0.0955)** : en moyenne, l’erreur entre les valeurs prédites et les vraies valeurs est de **0,095**.
# * **RMSE (0.1311)** : en tenant compte des grandes erreurs, l’erreur moyenne est de **0,13**.
#
# Plus ces valeurs sont **proches de 0**, **mieux le modèle prédit**.
# Ici, les erreurs sont **petites**, donc le modèle est **plutôt bon**.

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
X = df[features]
X_const = sm.add_constant(X)
X_const = X_const.astype(float)

# Séparer les données
X_train, X_test, y_train, y_test = train_test_split(X_const, y, test_size=0.3, random_state=42)

# Refit sur les données d'entraînement
model_rlm_train = sm.RLM(y_train, X_train, M=sm.robust.norms.HuberT()).fit()

# Prédictions
y_pred_train = model_rlm_train.predict(X_train)
y_pred_test = model_rlm_train.predict(X_test)

# Évaluer
print("R² train :", r2_score(y_train, y_pred_train))
print("R² test  :", r2_score(y_test, y_pred_test))
# Out:
# R² train : 0.8123540202000792
# R² test  : 0.7825707451957841

# %% [markdown]
# - Écart faible entre train et test → peu de sur-apprentissage (overfitting).
#
# - Le modèle est assez généralisable.
#
# - On peut dire qu’il modélise bien la relation entre les variables et l’AQI.
#
# | Jeu de données | R²    | Interprétation                                                                      |
# | -------------- | ----- | ----------------------------------------------------------------------------------- |
# | **Train**      | 0.812 | Le modèle explique **81 %** de la variance de l’AQI sur les données d’entraînement. |
# | **Test**       | 0.783 | Il explique **78 %** de la variance sur des données **non vues**.                   |

# %%
#print(X.dtypes)

# %%
# Prédictions du modèle RLM
y_pred = results_rlm.fittedvalues

#y_pred = model_rlm.fittedvalues

y_true = y

# Créer un DataFrame pour tracer les courbes
comparison_df = pd.DataFrame({
    'log_AQI_observé': y_true,
    'log_AQI_prédit': y_pred
})

# Tracer les courbes
plt.figure(figsize=(12, 5))
plt.plot(comparison_df['log_AQI_observé'].values, label='Observé', alpha=0.7)
plt.plot(comparison_df['log_AQI_prédit'].values, label='Prédit', alpha=0.7)
plt.title("Comparaison entre log(AQI) observé et prédit (modèle RLM)")
plt.xlabel("Observations")
plt.ylabel("log(AQI)")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Evolution des polluants dans le temps

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['periode'] = (df['Date'].dt.month >= 7).astype(int)

# Sélection de quelques variables explicatives pertinentes

features = ['PM2.5',
            #'PM10',
            #'CO', 
            'SO2' ,
            #'NO2',
            'Benzène',
            'PRESSURE_MAX_MB',
            #'SUNHOUR',                 
            #'SR_EST_W_m2' ,            
            'Toluène',                 
            'HUMIDITY_MAX_PERCENT',   
            #'HUMIDITY_EST_AVG',       
            #'MAX_TEMPERATURE_C',      
            #'TEMP_MOY',               
            #'MIN_TEMPERATURE_C',      
            'PRECIP_TOTAL_DAY_MM',    
            'O3',                     
            'WINDSPEED_MAX_KMH',     
            #'WINDSPEED_AVG_KMH',      
            'CLOUDCOVER_AVG_PERCENT',
            'weekday',
            'month',
            'saison_hiver',
            'saison_été',
            'saison_printemps',
            'log_AQI_lag1',
]

df_model = df[['log_AQI', 'periode'] + features].copy()


import warnings
warnings.filterwarnings("ignore", category=pd.errors.PerformanceWarning)

# Création automatique des variables d’interaction avec la période

for var in features:
    for m in range(1, 13):  # pour les 12 mois
        df_model[f"{var}_x_month_{m}"] = df_model[var] * (df_model['month'] == m).astype(int)

# Création dynamique de la liste complète des variables (features + interactions)
interaction_vars = [f"{var}_x_month" for var in features]
X_cols = features + ['month'] + interaction_vars


# Création de X et y
interaction_vars = [f'{var}_x_month_{m}' for var in features for m in range(1, 13)]
X = df_model[features + interaction_vars]
X_const = sm.add_constant(X)
y = df_model['log_AQI']

X_const = sm.add_constant(X)
X_const = X_const.astype(float)  # <- Très important
y = y.astype(float)              # <- Aussi important


# Modèle RLM robuste avec norme de Huber
model_rlm_interact = sm.RLM(y, X_const, M=sm.robust.norms.HuberT()).fit()

# Affichage du résumé
print(model_rlm_interact.summary())
# Out:
#                     Robust linear Model Regression Results
# ==============================================================================
# Dep. Variable:                log_AQI   No. Observations:                  365
# Model:                            RLM   Df Residuals:                      209
# Method:                          IRLS   Df Model:                          155
# Norm:                          HuberT
# Scale Est.:                       mad
# Cov Type:                          H1
# Date:                Wed, 16 Jul 2025
# Time:                        12:38:46
# No. Iterations:                    50
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# const                                 0.4771      0.386      1.237      0.216      -0.279       1.233
# PM2.5                                 0.0228      0.003      8.622      0.000       0.018       0.028
# SO2                                   0.0295      0.012      2.566      0.010       0.007       0.052
# Benzène                               0.1912      0.070      2.722      0.006       0.054       0.329
# PRESSURE_MAX_MB                       0.0002      0.001      0.181      0.856      -0.002       0.002
# Toluène                              -0.0407      0.020     -2.052      0.040      -0.080      -0.002
# HUMIDITY_MAX_PERCENT                 -0.0006      0.001     -0.790      0.430      -0.002       0.001
# PRECIP_TOTAL_DAY_MM                  -0.0020      0.008     -0.263      0.792      -0.017       0.013
# O3                                    0.0080      0.001     10.204      0.000       0.006       0.010
# WINDSPEED_MAX_KMH                     0.0048      0.001      4.038      0.000       0.002       0.007
# CLOUDCOVER_AVG_PERCENT                0.0007      0.000      2.573      0.010       0.000       0.001
# weekday                               0.0060      0.003      2.325      0.020       0.001       0.011
# month                                 0.1683      0.152      1.106      0.269      -0.130       0.467
# saison_hiver                          0.5035      0.455      1.106      0.269      -0.389       1.396
# saison_été                           -0.0261      0.139     -0.187      0.852      -0.299       0.247
# saison_printemps                      0.1083      0.195      0.557      0.578      -0.273       0.490
# log_AQI_lag1                          0.1308      0.026      4.952      0.000       0.079       0.183
# PM2.5_x_month_1                       0.0035      0.011      0.327      0.744      -0.018       0.025
# PM2.5_x_month_2                       0.0039      0.010      0.395      0.693      -0.015       0.023
# PM2.5_x_month_3                       0.0109      0.006      1.855      0.064      -0.001       0.022
# PM2.5_x_month_4                      -0.0288      0.015     -1.935      0.053      -0.058       0.000
# PM2.5_x_month_5                       0.0142      0.006      2.344      0.019       0.002       0.026
# PM2.5_x_month_6                      -0.0194      0.012     -1.556      0.120      -0.044       0.005
# PM2.5_x_month_7                      -0.0206      0.011     -1.798      0.072      -0.043       0.002
# PM2.5_x_month_8                      -0.0014      0.006     -0.241      0.810      -0.013       0.010
# PM2.5_x_month_9                      -0.0047      0.006     -0.725      0.468      -0.017       0.008
# PM2.5_x_month_10                      0.0214      0.010      2.063      0.039       0.001       0.042
# PM2.5_x_month_11                      0.0206      0.006      3.725      0.000       0.010       0.031
# PM2.5_x_month_12                      0.0230      0.009      2.591      0.010       0.006       0.040
# SO2_x_month_1                         0.0091      0.015      0.601      0.548      -0.021       0.039
# SO2_x_month_2                        -0.0239      0.020     -1.207      0.227      -0.063       0.015
# SO2_x_month_3                         0.0413      0.019      2.121      0.034       0.003       0.079
# SO2_x_month_4                         0.0483      0.040      1.216      0.224      -0.030       0.126
# SO2_x_month_5                        -0.0363      0.040     -0.897      0.369      -0.116       0.043
# SO2_x_month_6                         0.0672      0.067      1.004      0.315      -0.064       0.198
# SO2_x_month_7                         0.0608      0.073      0.837      0.402      -0.081       0.203
# SO2_x_month_8                        -0.0198      0.051     -0.385      0.701      -0.121       0.081
# SO2_x_month_9                        -0.0198      0.045     -0.441      0.659      -0.108       0.068
# SO2_x_month_10                       -0.0111      0.032     -0.343      0.731      -0.074       0.052
# SO2_x_month_11                       -0.0579      0.022     -2.647      0.008      -0.101      -0.015
# SO2_x_month_12                       -0.0284      0.019     -1.473      0.141      -0.066       0.009
# Benzène_x_month_1                     0.2684      0.196      1.371      0.170      -0.115       0.652
# Benzène_x_month_2                     0.1822      0.115      1.584      0.113      -0.043       0.408
# Benzène_x_month_3                     0.5588      0.178      3.146      0.002       0.211       0.907
# Benzène_x_month_4                    -0.1981      0.347     -0.570      0.569      -0.879       0.483
# Benzène_x_month_5                    -0.3121      0.344     -0.907      0.364      -0.986       0.362
# Benzène_x_month_6                    -0.2009      0.179     -1.124      0.261      -0.551       0.150
# Benzène_x_month_7                    -0.1777      0.226     -0.788      0.431      -0.620       0.265
# Benzène_x_month_8                     0.2773      0.314      0.883      0.377      -0.338       0.893
# Benzène_x_month_9                    -0.4879      0.286     -1.703      0.089      -1.049       0.074
# Benzène_x_month_10                   -0.3115      0.212     -1.470      0.141      -0.727       0.104
# Benzène_x_month_11                   -0.0020      0.195     -0.010      0.992      -0.384       0.380
# Benzène_x_month_12                    0.5947      0.311      1.914      0.056      -0.014       1.204
# PRESSURE_MAX_MB_x_month_1            -0.0018      0.002     -0.913      0.361      -0.006       0.002
# PRESSURE_MAX_MB_x_month_2             0.0012      0.001      0.802      0.423      -0.002       0.004
# PRESSURE_MAX_MB_x_month_3             0.0009      0.002      0.550      0.582      -0.002       0.004
# PRESSURE_MAX_MB_x_month_4            -0.0045      0.002     -2.225      0.026      -0.008      -0.001
# PRESSURE_MAX_MB_x_month_5             0.0041      0.003      1.347      0.178      -0.002       0.010
# PRESSURE_MAX_MB_x_month_6             0.0005      0.004      0.143      0.886      -0.006       0.007
# PRESSURE_MAX_MB_x_month_7             0.0038      0.006      0.628      0.530      -0.008       0.016
# PRESSURE_MAX_MB_x_month_8            -0.0035      0.004     -0.804      0.422      -0.012       0.005
# PRESSURE_MAX_MB_x_month_9             0.0037      0.003      1.355      0.175      -0.002       0.009
# PRESSURE_MAX_MB_x_month_10            0.0034      0.002      1.668      0.095      -0.001       0.007
# PRESSURE_MAX_MB_x_month_11            0.0020      0.003      0.813      0.416      -0.003       0.007
# PRESSURE_MAX_MB_x_month_12           -0.0097      0.003     -2.975      0.003      -0.016      -0.003
# Toluène_x_month_1                    -0.0737      0.050     -1.486      0.137      -0.171       0.024
# Toluène_x_month_2                     0.0193      0.021      0.900      0.368      -0.023       0.061
# Toluène_x_month_3                     0.0343      0.033      1.034      0.301      -0.031       0.099
# Toluène_x_month_4                     0.0269      0.096      0.281      0.779      -0.161       0.215
# Toluène_x_month_5                     0.0897      0.119      0.753      0.451      -0.144       0.323
# Toluène_x_month_6                     0.0386      0.027      1.424      0.154      -0.015       0.092
# Toluène_x_month_7                     0.0503      0.049      1.021      0.307      -0.046       0.147
# Toluène_x_month_8                    -0.0163      0.071     -0.229      0.819      -0.155       0.123
# Toluène_x_month_9                     0.1656      0.061      2.715      0.007       0.046       0.285
# Toluène_x_month_10                    0.0559      0.049      1.136      0.256      -0.041       0.152
# Toluène_x_month_11                   -0.2107      0.090     -2.333      0.020      -0.388      -0.034
# Toluène_x_month_12                   -0.2206      0.106     -2.083      0.037      -0.428      -0.013
# HUMIDITY_MAX_PERCENT_x_month_1        0.0033      0.002      1.701      0.089      -0.001       0.007
# HUMIDITY_MAX_PERCENT_x_month_2        0.0007      0.003      0.212      0.832      -0.006       0.007
# HUMIDITY_MAX_PERCENT_x_month_3       -0.0054      0.003     -2.063      0.039      -0.011      -0.000
# HUMIDITY_MAX_PERCENT_x_month_4       -0.0026      0.002     -1.062      0.288      -0.007       0.002
# HUMIDITY_MAX_PERCENT_x_month_5        0.0018      0.003      0.674      0.500      -0.003       0.007
# HUMIDITY_MAX_PERCENT_x_month_6        0.0018      0.003      0.597      0.550      -0.004       0.008
# HUMIDITY_MAX_PERCENT_x_month_7        0.0017      0.003      0.545      0.586      -0.004       0.008
# HUMIDITY_MAX_PERCENT_x_month_8        0.0020      0.002      1.050      0.294      -0.002       0.006
# HUMIDITY_MAX_PERCENT_x_month_9        0.0050      0.003      1.984      0.047    5.92e-05       0.010
# HUMIDITY_MAX_PERCENT_x_month_10       0.0043      0.003      1.682      0.093      -0.001       0.009
# HUMIDITY_MAX_PERCENT_x_month_11      -0.0077      0.002     -3.667      0.000      -0.012      -0.004
# HUMIDITY_MAX_PERCENT_x_month_12      -0.0054      0.002     -2.467      0.014      -0.010      -0.001
# PRECIP_TOTAL_DAY_MM_x_month_1        -0.0872      0.027     -3.218      0.001      -0.140      -0.034
# PRECIP_TOTAL_DAY_MM_x_month_2         0.0015      0.015      0.098      0.922      -0.028       0.031
# PRECIP_TOTAL_DAY_MM_x_month_3         0.0953      0.024      3.967      0.000       0.048       0.142
# PRECIP_TOTAL_DAY_MM_x_month_4        -0.0041      0.015     -0.282      0.778      -0.033       0.025
# PRECIP_TOTAL_DAY_MM_x_month_5        -0.0074      0.022     -0.328      0.743      -0.051       0.037
# PRECIP_TOTAL_DAY_MM_x_month_6        -0.0004      0.042     -0.009      0.993      -0.083       0.082
# PRECIP_TOTAL_DAY_MM_x_month_7        -0.0268      0.031     -0.877      0.381      -0.087       0.033
# PRECIP_TOTAL_DAY_MM_x_month_8        -0.0277      0.030     -0.933      0.351      -0.086       0.030
# PRECIP_TOTAL_DAY_MM_x_month_9        -0.0034      0.014     -0.236      0.813      -0.032       0.025
# PRECIP_TOTAL_DAY_MM_x_month_10       -0.0163      0.027     -0.604      0.546      -0.069       0.037
# PRECIP_TOTAL_DAY_MM_x_month_11        0.0666      0.038      1.756      0.079      -0.008       0.141
# PRECIP_TOTAL_DAY_MM_x_month_12        0.0079      0.026      0.306      0.759      -0.043       0.059
# O3_x_month_1                         -0.0002      0.003     -0.060      0.952      -0.007       0.007
# O3_x_month_2                         -0.0080      0.003     -2.611      0.009      -0.014      -0.002
# O3_x_month_3                          0.0072      0.003      2.637      0.008       0.002       0.013
# O3_x_month_4                          0.0018      0.004      0.490      0.624      -0.005       0.009
# O3_x_month_5                         -0.0025      0.002     -1.039      0.299      -0.007       0.002
# O3_x_month_6                          0.0069      0.003      2.680      0.007       0.002       0.012
# O3_x_month_7                          0.0057      0.002      2.314      0.021       0.001       0.010
# O3_x_month_8                          0.0053      0.002      2.470      0.014       0.001       0.009
# O3_x_month_9                          0.0003      0.003      0.100      0.920      -0.005       0.005
# O3_x_month_10                         0.0021      0.003      0.667      0.504      -0.004       0.008
# O3_x_month_11                        -0.0089      0.003     -3.294      0.001      -0.014      -0.004
# O3_x_month_12                        -0.0017      0.002     -0.677      0.498      -0.007       0.003
# WINDSPEED_MAX_KMH_x_month_1           0.0080      0.005      1.530      0.126      -0.002       0.018
# WINDSPEED_MAX_KMH_x_month_2           0.0048      0.004      1.316      0.188      -0.002       0.012
# WINDSPEED_MAX_KMH_x_month_3           0.0053      0.004      1.458      0.145      -0.002       0.012
# WINDSPEED_MAX_KMH_x_month_4           0.0006      0.004      0.140      0.888      -0.007       0.008
# WINDSPEED_MAX_KMH_x_month_5           0.0096      0.005      2.001      0.045       0.000       0.019
# WINDSPEED_MAX_KMH_x_month_6           0.0011      0.004      0.300      0.764      -0.006       0.008
# WINDSPEED_MAX_KMH_x_month_7           0.0005      0.004      0.125      0.900      -0.007       0.008
# WINDSPEED_MAX_KMH_x_month_8          -0.0059      0.005     -1.241      0.215      -0.015       0.003
# WINDSPEED_MAX_KMH_x_month_9          -0.0046      0.005     -0.912      0.362      -0.015       0.005
# WINDSPEED_MAX_KMH_x_month_10         -0.0073      0.004     -1.634      0.102      -0.016       0.001
# WINDSPEED_MAX_KMH_x_month_11          0.0019      0.004      0.488      0.626      -0.006       0.010
# WINDSPEED_MAX_KMH_x_month_12         -0.0091      0.004     -2.215      0.027      -0.017      -0.001
# CLOUDCOVER_AVG_PERCENT_x_month_1      0.0012      0.001      1.353      0.176      -0.001       0.003
# CLOUDCOVER_AVG_PERCENT_x_month_2      0.0024      0.001      2.307      0.021       0.000       0.004
# CLOUDCOVER_AVG_PERCENT_x_month_3     -0.0009      0.001     -0.848      0.396      -0.003       0.001
# CLOUDCOVER_AVG_PERCENT_x_month_4     -0.0005      0.001     -0.671      0.502      -0.002       0.001
# CLOUDCOVER_AVG_PERCENT_x_month_5     -0.0007      0.001     -0.687      0.492      -0.003       0.001
# CLOUDCOVER_AVG_PERCENT_x_month_6     -0.0005      0.001     -0.594      0.553      -0.002       0.001
# CLOUDCOVER_AVG_PERCENT_x_month_7     -0.0010      0.001     -0.864      0.388      -0.003       0.001
# CLOUDCOVER_AVG_PERCENT_x_month_8      0.0002      0.001      0.198      0.843      -0.001       0.002
# CLOUDCOVER_AVG_PERCENT_x_month_9      0.0001      0.001      0.110      0.912      -0.002       0.002
# CLOUDCOVER_AVG_PERCENT_x_month_10  3.639e-06      0.001      0.005      0.996      -0.002       0.002
# CLOUDCOVER_AVG_PERCENT_x_month_11    -0.0007      0.001     -0.950      0.342      -0.002       0.001
# CLOUDCOVER_AVG_PERCENT_x_month_12     0.0011      0.001      1.284      0.199      -0.001       0.003
# weekday_x_month_1                     0.0086      0.009      1.012      0.311      -0.008       0.025
# weekday_x_month_2                    -0.0144      0.009     -1.642      0.101      -0.032       0.003
# weekday_x_month_3                    -0.0029      0.007     -0.394      0.694      -0.017       0.012
# weekday_x_month_4                     0.0051      0.008      0.611      0.541      -0.011       0.022
# weekday_x_month_5                     0.0094      0.009      1.095      0.274      -0.007       0.026
# weekday_x_month_6                    -0.0019      0.012     -0.159      0.874      -0.025       0.021
# weekday_x_month_7                     0.0068      0.009      0.788      0.430      -0.010       0.024
# weekday_x_month_8                    -0.0031      0.009     -0.348      0.728      -0.021       0.014
# weekday_x_month_9                     0.0149      0.012      1.239      0.215      -0.009       0.038
# weekday_x_month_10                    0.0225      0.009      2.619      0.009       0.006       0.039
# weekday_x_month_11                   -0.0350      0.009     -4.074      0.000      -0.052      -0.018
# weekday_x_month_12                   -0.0041      0.010     -0.432      0.665      -0.023       0.015
# month_x_month_1                       0.6557      0.595      1.103      0.270      -0.510       1.821
# month_x_month_2                      -0.4255      0.550     -0.773      0.439      -1.504       0.653
# month_x_month_3                      -0.2952      0.493     -0.599      0.549      -1.262       0.671
# month_x_month_4                       1.4167      0.543      2.610      0.009       0.353       2.481
# month_x_month_5                      -0.7372      0.589     -1.252      0.211      -1.891       0.417
# month_x_month_6                      -0.0134      0.606     -0.022      0.982      -1.200       1.174
# month_x_month_7                      -0.5259      0.862     -0.610      0.542      -2.216       1.164
# month_x_month_8                       0.4105      0.561      0.732      0.464      -0.689       1.510
# month_x_month_9                      -0.5141      0.336     -1.529      0.126      -1.173       0.145
# month_x_month_10                     -0.3754      0.241     -1.561      0.119      -0.847       0.096
# month_x_month_11                     -0.1540      0.259     -0.593      0.553      -0.662       0.355
# month_x_month_12                      0.7260      0.293      2.481      0.013       0.152       1.300
# saison_hiver_x_month_1                0.6557      0.595      1.103      0.270      -0.510       1.821
# saison_hiver_x_month_2               -0.2127      0.275     -0.773      0.439      -0.752       0.327
# saison_hiver_x_month_3                     0          0        nan        nan           0           0
# saison_hiver_x_month_4                     0          0        nan        nan           0           0
# saison_hiver_x_month_5                     0          0        nan        nan           0           0
# saison_hiver_x_month_6                     0          0        nan        nan           0           0
# saison_hiver_x_month_7                     0          0        nan        nan           0           0
# saison_hiver_x_month_8                     0          0        nan        nan           0           0
# saison_hiver_x_month_9                     0          0        nan        nan           0           0
# saison_hiver_x_month_10                    0          0        nan        nan           0           0
# saison_hiver_x_month_11                    0          0        nan        nan           0           0
# saison_hiver_x_month_12               0.0605      0.024      2.481      0.013       0.013       0.108
# saison_été_x_month_1                       0          0        nan        nan           0           0
# saison_été_x_month_2                       0          0        nan        nan           0           0
# saison_été_x_month_3                       0          0        nan        nan           0           0
# saison_été_x_month_4                       0          0        nan        nan           0           0
# saison_été_x_month_5                       0          0        nan        nan           0           0
# saison_été_x_month_6                 -0.0022      0.101     -0.022      0.982      -0.200       0.196
# saison_été_x_month_7                 -0.0751      0.123     -0.610      0.542      -0.317       0.166
# saison_été_x_month_8                  0.0513      0.070      0.732      0.464      -0.086       0.189
# saison_été_x_month_9                       0          0        nan        nan           0           0
# saison_été_x_month_10                      0          0        nan        nan           0           0
# saison_été_x_month_11                      0          0        nan        nan           0           0
# saison_été_x_month_12                      0          0        nan        nan           0           0
# saison_printemps_x_month_1                 0          0        nan        nan           0           0
# saison_printemps_x_month_2                 0          0        nan        nan           0           0
# saison_printemps_x_month_3           -0.0984      0.164     -0.599      0.549      -0.421       0.224
# saison_printemps_x_month_4            0.3542      0.136      2.610      0.009       0.088       0.620
# saison_printemps_x_month_5           -0.1474      0.118     -1.252      0.211      -0.378       0.083
# saison_printemps_x_month_6                 0          0        nan        nan           0           0
# saison_printemps_x_month_7                 0          0        nan        nan           0           0
# saison_printemps_x_month_8                 0          0        nan        nan           0           0
# saison_printemps_x_month_9                 0          0        nan        nan           0           0
# saison_printemps_x_month_10                0          0        nan        nan           0           0
# saison_printemps_x_month_11                0          0        nan        nan           0           0
# saison_printemps_x_month_12                0          0        nan        nan           0           0
# log_AQI_lag1_x_month_1                0.1671      0.092      1.820      0.069      -0.013       0.347
# log_AQI_lag1_x_month_2                0.0859      0.104      0.828      0.408      -0.117       0.289
# log_AQI_lag1_x_month_3                0.0320      0.061      0.522      0.602      -0.088       0.152
# log_AQI_lag1_x_month_4               -0.1874      0.150     -1.252      0.211      -0.481       0.106
# log_AQI_lag1_x_month_5               -0.0181      0.085     -0.214      0.831      -0.185       0.148
# log_AQI_lag1_x_month_6               -0.1627      0.108     -1.507      0.132      -0.374       0.049
# log_AQI_lag1_x_month_7               -0.0751      0.111     -0.677      0.498      -0.292       0.142
# log_AQI_lag1_x_month_8               -0.0342      0.073     -0.467      0.640      -0.178       0.109
# log_AQI_lag1_x_month_9                0.1036      0.096      1.082      0.279      -0.084       0.291
# log_AQI_lag1_x_month_10              -0.1435      0.089     -1.615      0.106      -0.318       0.031
# log_AQI_lag1_x_month_11               0.1727      0.062      2.793      0.005       0.052       0.294
# log_AQI_lag1_x_month_12               0.1903      0.073      2.619      0.009       0.048       0.333
# =====================================================================================================
#
# If the model instance has been used for another fit with different fit parameters, then the fit options might not be the correct ones anymore .
